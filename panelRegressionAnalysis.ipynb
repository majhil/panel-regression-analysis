# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/blueprint 3.1.csv')
df1=pd.read_csv('/content/developed.csv')
df2=pd.read_csv('/content/developing.csv')
df.head(30)
# Out:
#         Country Code  Year  Annual_CO2_emissions  Life_Expectancy  \
# 0   Afghanistan  AFG  2013             9228517.0          62.1878
# 1   Afghanistan  AFG  2014             9086037.0          62.2599
# 2   Afghanistan  AFG  2015             9670181.0          62.2695
# 3   Afghanistan  AFG  2016             8906380.0          62.6459
# 4   Afghanistan  AFG  2017             9677441.0          62.4062
# 5   Afghanistan  AFG  2018            10601884.0          62.4434
# 6   Afghanistan  AFG  2019            10825145.0          62.9411
# 7   Afghanistan  AFG  2020            11605929.0          61.4537
# 8   Afghanistan  AFG  2021            10271881.0          60.4174
# 9   Afghanistan  AFG  2022            10557803.0          65.6170
# 10  Afghanistan  AFG  2023            11020218.0          66.0346
# 11      Albania  ALB  2013             5287465.0          77.9951
# 12      Albania  ALB  2014             5999650.0          78.0291
# 13      Albania  ALB  2015             4712144.0          78.3580
# 14      Albania  ALB  2016             4631979.0          78.6433
# 15      Albania  ALB  2017             5293048.0          78.9003
# 16      Albania  ALB  2018             4894953.0          79.2377
# 17      Albania  ALB  2019             4826944.0          79.4669
# 18      Albania  ALB  2020             4711145.0          77.8241
# 19      Albania  ALB  2021             5134120.0          76.8442
# 20      Albania  ALB  2022             5173371.0          78.7688
# 21      Albania  ALB  2023             5144279.0          79.6019
# 22      Algeria  DZA  2013           140786380.0          74.8095
# 23      Algeria  DZA  2014           151282780.0          74.9923
# 24      Algeria  DZA  2015           160087460.0          75.1589
# 25      Algeria  DZA  2016           158481630.0          75.3099
# 26      Algeria  DZA  2017           165173870.0          75.4313
# 27      Algeria  DZA  2018           172705260.0          75.5554
# 28      Algeria  DZA  2019           179906580.0          75.6818
# 29      Algeria  DZA  2020           168177860.0          73.2568
#
#     GDP_per_capita  Military_Expenditure  Infant_Mortality_Rate  \
# 0        3046.5798          1.834217e+08               5.806994
# 1        3017.9426          2.237220e+08               5.624206
# 2        2967.6921          1.789139e+08               5.458732
# 3        2958.7854          1.772400e+08               5.303607
# 4        2952.9990          1.742727e+08               5.153941
# 5        2902.3920          1.903353e+08               5.013797
# 6        2927.2450          2.281066e+08               4.875166
# 7        2769.6858          2.639042e+08               4.738095
# 8        2144.1665          2.686006e+08               4.606694
# 9        1981.7102          2.575638e+08               4.476813
# 10       1992.4244          2.671095e+08               4.301709
# 11      12727.0830          2.061217e+08               0.931842
# 12      12979.7650          2.003290e+08               0.883420
# 13      13306.4430          1.744484e+08               0.851854
# 14      13769.5470          1.679016e+08               0.836194
# 15      14306.2990          1.742453e+08               0.830237
# 16      14918.0810          1.886156e+08               0.831054
# 17      15290.7770          2.121836e+08               0.834857
# 18      14869.2200          2.056966e+08               0.838682
# 19      16353.8090          2.178605e+08               0.841297
# 20      17352.8540          2.286932e+08               0.839564
# 21      18244.2930          3.399298e+08               0.812086
# 22      14778.1910          8.768655e+09               2.236292
# 23      15073.7630          1.009860e+10               2.203663
# 24      15239.5180          1.056503e+10               2.172101
# 25      15511.6860          1.059656e+10               2.138278
# 26      15427.6640          1.003547e+10               2.100450
# 27      15343.4260          9.624504e+09               2.057985
# 28      15199.1990          1.038321e+10               2.013133
# 29      14194.1550          1.014107e+10               1.965650
#
#     health_expenditure_per_capita
# 0                      178.079030
# 1                      202.261550
# 2                      215.725230
# 3                      239.188750
# 4                      264.543980
# 5                      299.787500
# 6                      321.499080
# 7                      322.499300
# 8                      363.611180
# 9                      377.981953
# 10                     399.038003
# 11                     666.017640
# 12                     725.737700
# 13                     753.180050
# 14                     811.422060
# 15                     838.417000
# 16                     896.791400
# 17                     981.879000
# 18                    1044.568600
# 19                    1131.669100
# 20                    1152.342432
# 21                    1208.373528
# 22                     790.969900
# 23                     854.943540
# 24                     840.585800
# 25                     769.958440
# 26                     759.241300
# 27                     766.858640
# 28                     710.995850
# 29                     706.201350

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1650 entries, 0 to 1649
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        1650 non-null   object
#  1   Code                           1650 non-null   object
#  2   Year                           1650 non-null   int64
#  3   Annual_CO2_emissions           1650 non-null   float64
#  4   Life_Expectancy                1650 non-null   float64
#  5   GDP_per_capita                 1650 non-null   float64
#  6   Military_Expenditure           1650 non-null   float64
#  7   Infant_Mortality_Rate          1650 non-null   float64
#  8   health_expenditure_per_capita  1650 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 116.1+ KB

# %%
df.isnull().sum()
# Out:
# Country                          0
# Code                             0
# Year                             0
# Annual_CO2_emissions             0
# Life_Expectancy                  0
# GDP_per_capita                   0
# Military_Expenditure             0
# Infant_Mortality_Rate            0
# health_expenditure_per_capita    0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Annual_CO2_emissions  Life_Expectancy  GDP_per_capita  \
# count  1650.000000          1.650000e+03      1650.000000     1650.000000
# mean   2018.000000          4.705683e+08        71.790069    24784.789892
# std       3.163236          3.094252e+09         8.175291    25588.213507
# min    2013.000000          1.172480e+05        18.817700      828.861100
# 25%    2015.000000          5.977188e+06        65.638175     5584.006425
# 50%    2018.000000          2.226629e+07        73.031200    15044.990500
# 75%    2021.000000          1.052747e+08        78.015050    38043.420000
# max    2023.000000          3.779157e+10        84.712300   137947.340000
#
#        Military_Expenditure  Infant_Mortality_Rate  \
# count          1.650000e+03            1650.000000
# mean           2.721143e+10               2.204205
# std            1.806913e+11               2.060839
# min            2.430750e+05               0.121474
# 25%            2.250186e+08               0.492669
# 50%            9.899220e+08               1.387961
# 75%            5.374988e+09               3.411241
# max            2.390000e+12               9.787414
#
#        health_expenditure_per_capita
# count                    1650.000000
# mean                     1637.461495
# std                      2018.837345
# min                        12.501416
# 25%                       212.102940
# 50%                       792.667110
# 75%                      2308.823575
# max                     12811.315270

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame

# Select only numerical columns for correlation
numerical_df = df.select_dtypes(include=np.number)

# Calculate correlation matrix
correlation_matrix = numerical_df.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix of Variables')
plt.show()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                    Year  Annual_CO2_emissions  \
# Year                           1.000000              0.003217
# Annual_CO2_emissions           0.003217              1.000000
# Life_Expectancy                0.055441              0.045592
# GDP_per_capita                 0.040103              0.005034
# Military_Expenditure           0.011080              0.953647
# Infant_Mortality_Rate         -0.089903             -0.012968
# health_expenditure_per_capita  0.118640              0.043606
#
#                                Life_Expectancy  GDP_per_capita  \
# Year                                  0.055441        0.040103
# Annual_CO2_emissions                  0.045592        0.005034
# Life_Expectancy                       1.000000        0.717345
# GDP_per_capita                        0.717345        1.000000
# Military_Expenditure                  0.059009        0.055489
# Infant_Mortality_Rate                -0.917251       -0.623380
# health_expenditure_per_capita         0.695654        0.843977
#
#                                Military_Expenditure  Infant_Mortality_Rate  \
# Year                                       0.011080              -0.089903
# Annual_CO2_emissions                       0.953647              -0.012968
# Life_Expectancy                            0.059009              -0.917251
# GDP_per_capita                             0.055489              -0.623380
# Military_Expenditure                       1.000000              -0.023781
# Infant_Mortality_Rate                     -0.023781               1.000000
# health_expenditure_per_capita              0.150430              -0.588794
#
#                                health_expenditure_per_capita
# Year                                                0.118640
# Annual_CO2_emissions                                0.043606
# Life_Expectancy                                     0.695654
# GDP_per_capita                                      0.843977
# Military_Expenditure                                0.150430
# Infant_Mortality_Rate                              -0.588794
# health_expenditure_per_capita                       1.000000

# %%
df.shape
# Out:
# (1650, 9)

# %%
df1.shape
# Out:
# (957, 9)

# %%
df2.shape
# Out:
# (693, 9)

# %%
df = df.set_index(['Code', 'Year'])
df1 = df1.set_index(['Code', 'Year'])
df2 = df2.set_index(['Code', 'Year'])

# %%
df.shape
# Out:
# (1650, 7)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
# !pip install linearmodels
import linearmodels
from linearmodels.panel import PanelOLS
from linearmodels import RandomEffects
from scipy.stats import linregress
# Out:
# Requirement already satisfied: linearmodels in /usr/local/lib/python3.11/dist-packages (6.1)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.24.3)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (2.2.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.14.1)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (0.14.4)
# Requirement already satisfied: mypy-extensions>=0.4 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.0.0)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (3.0.12)
# Requirement already satisfied: pyhdfe>=0.1 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (0.2.0)
# Requirement already satisfied: formulaic>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.1.1)
# Requirement already satisfied: setuptools-scm<9.0.0,>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (8.2.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (4.13.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2025.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (24.2)
# Requirement already satisfied: setuptools>=61 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (75.2.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.0->linearmodels) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->linearmodels) (1.17.0)

# %%
df.columns
# Out:
# Index(['Country', 'Annual_CO2_emissions', 'Life_Expectancy', 'GDP_per_capita',
#        'Military_Expenditure', 'Infant_Mortality_Rate',
#        'health_expenditure_per_capita'],
#       dtype='object')

# %%
pooled_ols = smf.ols('Life_Expectancy ~ Annual_CO2_emissions  + GDP_per_capita  + Infant_Mortality_Rate + Military_Expenditure + health_expenditure_per_capita', data=df).fit()
print(pooled_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     2565.
# Date:                Mon, 21 Apr 2025   Prob (F-statistic):               0.00
# Time:                        06:29:07   Log-Likelihood:                -4013.2
# No. Observations:                1650   AIC:                             8038.
# Df Residuals:                    1644   BIC:                             8071.
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        76.1484      0.179    426.420      0.000      75.798      76.499
# Annual_CO2_emissions           6.135e-10    8.1e-11      7.570      0.000    4.55e-10    7.72e-10
# GDP_per_capita                 3.166e-05   5.32e-06      5.953      0.000    2.12e-05    4.21e-05
# Infant_Mortality_Rate            -2.9396      0.043    -67.964      0.000      -3.024      -2.855
# Military_Expenditure          -9.742e-12   1.41e-12     -6.889      0.000   -1.25e-11   -6.97e-12
# health_expenditure_per_capita     0.0008   7.07e-05     11.337      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                      880.291   Durbin-Watson:                   0.522
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27617.850
# Skew:                          -1.899   Prob(JB):                         0.00
# Kurtosis:                      22.680   Cond. No.                     4.90e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.9e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pooled_ols = smf.ols('Life_Expectancy ~ Annual_CO2_emissions  + GDP_per_capita  + Infant_Mortality_Rate + Military_Expenditure + health_expenditure_per_capita', data=df1).fit()
print(pooled_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     633.5
# Date:                Mon, 21 Apr 2025   Prob (F-statistic):          1.07e-299
# Time:                        06:29:07   Log-Likelihood:                -2192.4
# No. Observations:                 957   AIC:                             4397.
# Df Residuals:                     951   BIC:                             4426.
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        76.3743      0.218    349.702      0.000      75.946      76.803
# Annual_CO2_emissions           5.768e-10   7.19e-11      8.028      0.000    4.36e-10    7.18e-10
# GDP_per_capita                 2.779e-05   4.79e-06      5.799      0.000    1.84e-05    3.72e-05
# Infant_Mortality_Rate            -2.9508      0.098    -29.999      0.000      -3.144      -2.758
# Military_Expenditure          -9.241e-12   1.26e-12     -7.348      0.000   -1.17e-11   -6.77e-12
# health_expenditure_per_capita     0.0008   6.47e-05     12.404      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       20.703   Durbin-Watson:                   0.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.125
# Skew:                          -0.320   Prob(JB):                     4.27e-05
# Kurtosis:                       2.692   Cond. No.                     7.15e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.15e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pooled_ols = smf.ols('Life_Expectancy ~ Annual_CO2_emissions  + GDP_per_capita  + Infant_Mortality_Rate + Military_Expenditure + health_expenditure_per_capita', data=df2).fit()
print(pooled_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     459.6
# Date:                Mon, 21 Apr 2025   Prob (F-statistic):          2.27e-216
# Time:                        06:29:07   Log-Likelihood:                -1769.5
# No. Observations:                 693   AIC:                             3551.
# Df Residuals:                     687   BIC:                             3578.
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        75.8481      0.530    143.163      0.000      74.808      76.888
# Annual_CO2_emissions          -1.188e-08   3.17e-09     -3.752      0.000   -1.81e-08   -5.66e-09
# GDP_per_capita                    0.0001    6.9e-05      1.659      0.098    -2.1e-05       0.000
# Infant_Mortality_Rate            -2.9175      0.083    -35.147      0.000      -3.080      -2.755
# Military_Expenditure           4.644e-10   1.12e-10      4.140      0.000    2.44e-10    6.85e-10
# health_expenditure_per_capita    -0.0012      0.001     -1.256      0.210      -0.003       0.001
# ==============================================================================
# Omnibus:                      517.629   Durbin-Watson:                   0.706
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23187.454
# Skew:                          -2.833   Prob(JB):                         0.00
# Kurtosis:                      30.765   Cond. No.                     4.12e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.12e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.diagnostic import het_breuschpagan
bp_test = het_breuschpagan(pooled_ols.resid, pooled_ols.model.exog)
print(bp_test)
# Out:
# (25.801352710817287, 9.750998595545254e-05, 5.3134188399062365, 8.446701088796768e-05)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.outliers_influence import reset_ramsey
reset_test = reset_ramsey(pooled_ols, degree=2)
print(reset_test)
# Out:
# <F test: F=23.117973169646653, p=1.873627742526033e-06, df_denom=686, df_num=1>

# %%
fe_model = PanelOLS.from_formula('Life_Expectancy ~ Annual_CO2_emissions  + GDP_per_capita  + Infant_Mortality_Rate + Military_Expenditure + health_expenditure_per_capita', data=df)
fe_result = fe_model.fit()
print(fe_result)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.8378
# Estimator:                   PanelOLS   R-squared (Between):              0.8445
# No. Observations:                1650   R-squared (Within):              -17.563
# Date:                Mon, Apr 21 2025   R-squared (Overall):              0.8378
# Time:                        06:29:07   Log-likelihood                   -7903.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1699.0
# Entities:                         150   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                  F(5,1645)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             1699.0
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                  F(5,1645)
# Avg Obs:                       150.00
# Min Obs:                       150.00
# Max Obs:                       150.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# Annual_CO2_emissions           7.694e-09  8.377e-10     9.1846     0.0000   6.051e-09   9.337e-09
# GDP_per_capita                    0.0009  5.195e-05     17.231     0.0000      0.0008      0.0010
# Infant_Mortality_Rate             12.633     0.2448     51.609     0.0000      12.153      13.113
# Military_Expenditure          -1.283e-10  1.464e-11    -8.7601     0.0000   -1.57e-10  -9.956e-11
# health_expenditure_per_capita     0.0065     0.0007     8.8343     0.0000      0.0050      0.0079
# =================================================================================================

# %%
from linearmodels import RandomEffects
re_model1 = RandomEffects.from_formula('Life_Expectancy ~ Annual_CO2_emissions  + GDP_per_capita  + Infant_Mortality_Rate + Military_Expenditure + health_expenditure_per_capita', data=df)
re_result = re_model1.fit()
print(re_result)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.1147
# Estimator:              RandomEffects   R-squared (Between):             -0.0514
# No. Observations:                1650   R-squared (Within):               0.1963
# Date:                Mon, Apr 21 2025   R-squared (Overall):             -0.0513
# Time:                        06:29:08   Log-likelihood                   -3106.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      42.620
# Entities:                         150   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                  F(5,1645)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             42.620
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                  F(5,1645)
# Avg Obs:                       150.00
# Min Obs:                       150.00
# Max Obs:                       150.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# Annual_CO2_emissions           7.522e-10  4.683e-10     1.6061     0.1084  -1.664e-10   1.671e-09
# GDP_per_capita                 8.052e-05  1.677e-05     4.8010     0.0000   4.763e-05      0.0001
# Infant_Mortality_Rate            -1.9173     0.1478    -12.974     0.0000     -2.2071     -1.6274
# Military_Expenditure          -2.152e-12  3.566e-12    -0.6034     0.5463  -9.147e-12   4.843e-12
# health_expenditure_per_capita    -0.0001     0.0001    -1.2169     0.2238     -0.0004   9.107e-05
# =================================================================================================

# %%
from linearmodels.panel import compare
modelscompare = compare({'FE': fe_result, 'RE': re_result})
print("COMPARE THE RESULTS:", modelscompare)
# Out:
# COMPARE THE RESULTS:                           Model Comparison
# ===================================================================
#                                                FE                RE
# -------------------------------------------------------------------
# Dep. Variable                     Life_Expectancy   Life_Expectancy
# Estimator                                PanelOLS     RandomEffects
# No. Observations                             1650              1650
# Cov. Est.                              Unadjusted        Unadjusted
# R-squared                                  0.8378            0.1147
# R-Squared (Within)                        -17.563            0.1963
# R-Squared (Between)                        0.8445           -0.0514
# R-Squared (Overall)                        0.8378           -0.0513
# F-statistic                                1699.0            42.620
# P-value (F-stat)                           0.0000            0.0000
# =============================== ================= =================
# Annual_CO2_emissions                    7.694e-09         7.522e-10
#                                          (9.1846)          (1.6061)
# GDP_per_capita                             0.0009         8.052e-05
#                                          (17.231)          (4.8010)
# Infant_Mortality_Rate                      12.633           -1.9173
#                                          (51.609)         (-12.974)
# Military_Expenditure                   -1.283e-10        -2.152e-12
#                                         (-8.7601)         (-0.6034)
# health_expenditure_per_capita              0.0065           -0.0001
#                                          (8.8343)         (-1.2169)
# -------------------------------------------------------------------
#
# T-stats reported in parentheses

# %%
from scipy import stats
from linearmodels.panel import PanelOLS, RandomEffects
b_fe = fe_result.params[['Annual_CO2_emissions','Military_Expenditure','GDP_per_capita', 'Infant_Mortality_Rate', 'health_expenditure_per_capita']]
b_re = re_result.params[['Annual_CO2_emissions','Military_Expenditure','GDP_per_capita', 'Infant_Mortality_Rate', 'health_expenditure_per_capita']]

beta_diff = b_fe - b_re

V_fe = fe_result.cov.iloc[:len(b_fe), :len(b_fe)]
V_re = re_result.cov.iloc[:len(b_re), :len(b_re)]

V_diff = V_fe - V_re

chi2_stat = np.dot(np.dot(beta_diff.T, np.linalg.inv(V_diff)), beta_diff)
df_len = len(b_fe)
p_value = 1 - stats.chi2.cdf(chi2_stat, df_len)

print("Hausman test statistic:", chi2_stat)
print("Degrees of freedom:", df_len)
print("P-value:", p_value)

if p_value <0.05:
  print("Reject the null hypothesis: Fixed Effects model is preferred")
else:
  print("Fail to reject the null hypothesis: Random Effects model is preffered")
# Out:
# Hausman test statistic: -5.373731467265638e+24
# Degrees of freedom: 5
# P-value: 1.0
# Fail to reject the null hypothesis: Random Effects model is preffered

# %%
from linearmodels import RandomEffects
re_model2 = RandomEffects(df['Life_Expectancy'], sm.add_constant(df[['Annual_CO2_emissions', 'Military_Expenditure','GDP_per_capita', 'Infant_Mortality_Rate', 'health_expenditure_per_capita']])).fit()
print(re_model2.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.5119
# Estimator:              RandomEffects   R-squared (Between):              0.8897
# No. Observations:                1650   R-squared (Within):               0.1963
# Date:                Mon, Apr 21 2025   R-squared (Overall):              0.8699
# Time:                        06:29:08   Log-likelihood                   -2786.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      344.89
# Entities:                         150   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                  F(5,1644)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             344.89
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                  F(5,1644)
# Avg Obs:                       150.00
# Min Obs:                       150.00
# Max Obs:                       150.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# const                             76.287     0.3741     203.92     0.0000      75.553      77.021
# Annual_CO2_emissions           1.912e-10  1.484e-10     1.2881     0.1979  -9.993e-11   4.823e-10
# Military_Expenditure          -1.911e-12  2.348e-12    -0.8142     0.4156  -6.516e-12   2.693e-12
# GDP_per_capita                 6.963e-05  9.485e-06     7.3415     0.0000   5.103e-05   8.824e-05
# Infant_Mortality_Rate            -2.8112     0.0857    -32.792     0.0000     -2.9794     -2.6431
# health_expenditure_per_capita -3.909e-05  9.028e-05    -0.4329     0.6651     -0.0002      0.0001
# =================================================================================================

# %%
from linearmodels import RandomEffects
#developed
re_model3 = RandomEffects(df1['Life_Expectancy'], sm.add_constant(df1[['Annual_CO2_emissions', 'Military_Expenditure','GDP_per_capita', 'Infant_Mortality_Rate', 'health_expenditure_per_capita']])).fit()
print(re_model3.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.2676
# Estimator:              RandomEffects   R-squared (Between):              0.6956
# No. Observations:                 957   R-squared (Within):               0.0873
# Date:                Mon, Apr 21 2025   R-squared (Overall):              0.6773
# Time:                        06:29:08   Log-likelihood                   -1236.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      69.503
# Entities:                          87   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                   F(5,951)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             69.503
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                   F(5,951)
# Avg Obs:                       87.000
# Min Obs:                       87.000
# Max Obs:                       87.000
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# const                             77.435     0.4120     187.95     0.0000      76.627      78.244
# Annual_CO2_emissions           1.178e-10  1.173e-10     1.0044     0.3154  -1.124e-10   3.479e-10
# Military_Expenditure          -1.275e-12  1.724e-12    -0.7393     0.4599  -4.658e-12   2.109e-12
# GDP_per_capita                 5.003e-05  7.717e-06     6.4830     0.0000   3.488e-05   6.517e-05
# Infant_Mortality_Rate            -2.5998     0.1767    -14.710     0.0000     -2.9466     -2.2529
# health_expenditure_per_capita -5.815e-05  6.458e-05    -0.9004     0.3681     -0.0002   6.858e-05
# =================================================================================================

# %%
from linearmodels import RandomEffects
#developing
re_model4 = RandomEffects(df2['Life_Expectancy'], sm.add_constant(df2[['Annual_CO2_emissions', 'Military_Expenditure','GDP_per_capita', 'Infant_Mortality_Rate', 'health_expenditure_per_capita']])).fit()
print(re_model4.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.4037
# Estimator:              RandomEffects   R-squared (Between):              0.8034
# No. Observations:                 693   R-squared (Within):               0.2508
# Date:                Mon, Apr 21 2025   R-squared (Overall):              0.7570
# Time:                        06:29:08   Log-likelihood                   -1353.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      93.003
# Entities:                          63   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                   F(5,687)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             93.003
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                   F(5,687)
# Avg Obs:                       63.000
# Min Obs:                       63.000
# Max Obs:                       63.000
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# const                             74.661     0.9465     78.883     0.0000      72.803      76.519
# Annual_CO2_emissions           2.944e-10  3.183e-09     0.0925     0.9263  -5.955e-09   6.544e-09
# Military_Expenditure           -1.35e-11  1.083e-10    -0.1246     0.9009  -2.262e-10   1.992e-10
# GDP_per_capita                    0.0003     0.0001     2.7187     0.0067   8.174e-05      0.0005
# Infant_Mortality_Rate            -2.6699     0.1439    -18.556     0.0000     -2.9524     -2.3874
# health_expenditure_per_capita    -0.0031     0.0012    -2.7014     0.0071     -0.0054     -0.0009
# =================================================================================================

# %%
from linearmodels import RandomEffects
re_model5 = RandomEffects.from_formula('Life_Expectancy ~ 1 + Annual_CO2_emissions + GDP_per_capita + Military_Expenditure + Infant_Mortality_Rate + health_expenditure_per_capita', data=df).fit()
print(re_model5.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.5119
# Estimator:              RandomEffects   R-squared (Between):              0.8897
# No. Observations:                1650   R-squared (Within):               0.1963
# Date:                Mon, Apr 21 2025   R-squared (Overall):              0.8699
# Time:                        06:29:08   Log-likelihood                   -2786.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      344.89
# Entities:                         150   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                  F(5,1644)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             344.89
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                  F(5,1644)
# Avg Obs:                       150.00
# Min Obs:                       150.00
# Max Obs:                       150.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# Intercept                         76.287     0.3741     203.92     0.0000      75.553      77.021
# Annual_CO2_emissions           1.912e-10  1.484e-10     1.2881     0.1979  -9.993e-11   4.823e-10
# GDP_per_capita                 6.963e-05  9.485e-06     7.3415     0.0000   5.103e-05   8.824e-05
# Military_Expenditure          -1.911e-12  2.348e-12    -0.8142     0.4156  -6.516e-12   2.693e-12
# Infant_Mortality_Rate            -2.8112     0.0857    -32.792     0.0000     -2.9794     -2.6431
# health_expenditure_per_capita -3.909e-05  9.028e-05    -0.4329     0.6651     -0.0002      0.0001
# =================================================================================================

# %%
from linearmodels import RandomEffects
re_model6 = RandomEffects.from_formula('Life_Expectancy ~ Annual_CO2_emissions +health_expenditure_per_capita + GDP_per_capita + Military_Expenditure + Infant_Mortality_Rate', data=df).fit()
print(re_model6.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.1147
# Estimator:              RandomEffects   R-squared (Between):             -0.0514
# No. Observations:                1650   R-squared (Within):               0.1963
# Date:                Mon, Apr 21 2025   R-squared (Overall):             -0.0513
# Time:                        06:29:08   Log-likelihood                   -3106.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      42.620
# Entities:                         150   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                  F(5,1645)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             42.620
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                  F(5,1645)
# Avg Obs:                       150.00
# Min Obs:                       150.00
# Max Obs:                       150.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# Annual_CO2_emissions           7.522e-10  4.683e-10     1.6061     0.1084  -1.664e-10   1.671e-09
# health_expenditure_per_capita    -0.0001     0.0001    -1.2169     0.2238     -0.0004   9.107e-05
# GDP_per_capita                 8.052e-05  1.677e-05     4.8010     0.0000   4.763e-05      0.0001
# Military_Expenditure          -2.152e-12  3.566e-12    -0.6034     0.5463  -9.147e-12   4.843e-12
# Infant_Mortality_Rate            -1.9173     0.1478    -12.974     0.0000     -2.2071     -1.6274
# =================================================================================================

# %%
from linearmodels import RandomEffects
re_model7 = RandomEffects.from_formula('Life_Expectancy ~ 1 + Annual_CO2_emissions + GDP_per_capita + Infant_Mortality_Rate + health_expenditure_per_capita', data=df).fit()
print(re_model7.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                        0.5052
# Estimator:              RandomEffects   R-squared (Between):              0.8886
# No. Observations:                1650   R-squared (Within):               0.1970
# Date:                Mon, Apr 21 2025   R-squared (Overall):              0.8687
# Time:                        06:29:08   Log-likelihood                   -2783.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      419.87
# Entities:                         150   P-value                           0.0000
# Avg Obs:                       11.000   Distribution:                  F(4,1645)
# Min Obs:                       11.000
# Max Obs:                       11.000   F-statistic (robust):             419.87
#                                         P-value                           0.0000
# Time periods:                      11   Distribution:                  F(4,1645)
# Avg Obs:                       150.00
# Min Obs:                       150.00
# Max Obs:                       150.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# Intercept                         76.303     0.3768     202.50     0.0000      75.563      77.042
# Annual_CO2_emissions           8.234e-11  6.623e-11     1.2432     0.2140  -4.757e-11   2.122e-10
# GDP_per_capita                 7.016e-05  9.519e-06     7.3712     0.0000   5.149e-05   8.883e-05
# Infant_Mortality_Rate            -2.8081     0.0863    -32.555     0.0000     -2.9773     -2.6389
# health_expenditure_per_capita -6.148e-05  8.776e-05    -0.7005     0.4837     -0.0002      0.0001
# =================================================================================================

# %%
# !pip install linearmodels --upgrade
# Out:
# Requirement already satisfied: linearmodels in /usr/local/lib/python3.11/dist-packages (6.1)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.24.3)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (2.2.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.14.1)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (0.14.4)
# Requirement already satisfied: mypy-extensions>=0.4 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.0.0)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (3.0.12)
# Requirement already satisfied: pyhdfe>=0.1 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (0.2.0)
# Requirement already satisfied: formulaic>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.1.1)
# Requirement already satisfied: setuptools-scm<9.0.0,>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (8.2.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (4.13.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2025.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (24.2)
# Requirement already satisfied: setuptools>=61 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (75.2.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.0->linearmodels) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->linearmodels) (1.17.0)

# %%
# !pip install numpy==1.24.3
# Out:
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.11/dist-packages (1.24.3)

# %%
# !pip install pydynpd --upgrade
# !pip install arch
import statsmodels
import arch
import pydynpd
from pydynpd import regression
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.stattools import acf, pacf
from arch.unitroot import PhillipsPerron, KPSS, ADF # PhillipsPerson has been renamed to PhillipsPerron
# Out:
# Collecting pydynpd
#   Using cached pydynpd-0.2.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pydynpd) (1.24.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pydynpd) (1.14.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from pydynpd) (3.16.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pydynpd) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pydynpd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pydynpd) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pydynpd) (2025.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable->pydynpd) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pydynpd) (1.17.0)
# Using cached pydynpd-0.2.1-py3-none-any.whl (26 kB)
# Installing collected packages: pydynpd
# Successfully installed pydynpd-0.2.1
# Collecting arch
#   Downloading arch-7.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from arch) (1.24.3)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.11/dist-packages (from arch) (1.14.1)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.11/dist-packages (from arch) (2.2.2)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.11/dist-packages (from arch) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->arch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->arch) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.12->arch) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.12->arch) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->arch) (1.17.0)
# Downloading arch-7.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (985 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.3/985.3 kB 15.4 MB/s eta 0:00:00
# Installing collected packages: arch
# Successfully installed arch-7.2.0

# %%
df.head()
# Out:
#                Country  Annual_CO2_emissions  Life_Expectancy  GDP_per_capita  \
# Code Year
# AFG  2013  Afghanistan             9228517.0          62.1878       3046.5798
#      2014  Afghanistan             9086037.0          62.2599       3017.9426
#      2015  Afghanistan             9670181.0          62.2695       2967.6921
#      2016  Afghanistan             8906380.0          62.6459       2958.7854
#      2017  Afghanistan             9677441.0          62.4062       2952.9990
#
#            Military_Expenditure  Infant_Mortality_Rate  \
# Code Year
# AFG  2013           183421710.0               5.806994
#      2014           223721970.0               5.624206
#      2015           178913870.0               5.458732
#      2016           177240050.0               5.303607
#      2017           174272690.0               5.153941
#
#            health_expenditure_per_capita
# Code Year
# AFG  2013                      178.07903
#      2014                      202.26155
#      2015                      215.72523
#      2016                      239.18875
#      2017                      264.54398

# %%
df = df.reset_index(drop=False)
df1 = df1.reset_index(drop=False)
df2 = df2.reset_index(drop=False)
df.head(20)
# Out:
#    Code  Year      Country  Annual_CO2_emissions  Life_Expectancy  \
# 0   AFG  2013  Afghanistan             9228517.0          62.1878
# 1   AFG  2014  Afghanistan             9086037.0          62.2599
# 2   AFG  2015  Afghanistan             9670181.0          62.2695
# 3   AFG  2016  Afghanistan             8906380.0          62.6459
# 4   AFG  2017  Afghanistan             9677441.0          62.4062
# 5   AFG  2018  Afghanistan            10601884.0          62.4434
# 6   AFG  2019  Afghanistan            10825145.0          62.9411
# 7   AFG  2020  Afghanistan            11605929.0          61.4537
# 8   AFG  2021  Afghanistan            10271881.0          60.4174
# 9   AFG  2022  Afghanistan            10557803.0          65.6170
# 10  AFG  2023  Afghanistan            11020218.0          66.0346
# 11  ALB  2013      Albania             5287465.0          77.9951
# 12  ALB  2014      Albania             5999650.0          78.0291
# 13  ALB  2015      Albania             4712144.0          78.3580
# 14  ALB  2016      Albania             4631979.0          78.6433
# 15  ALB  2017      Albania             5293048.0          78.9003
# 16  ALB  2018      Albania             4894953.0          79.2377
# 17  ALB  2019      Albania             4826944.0          79.4669
# 18  ALB  2020      Albania             4711145.0          77.8241
# 19  ALB  2021      Albania             5134120.0          76.8442
#
#     GDP_per_capita  Military_Expenditure  Infant_Mortality_Rate  \
# 0        3046.5798           183421710.0               5.806994
# 1        3017.9426           223721970.0               5.624206
# 2        2967.6921           178913870.0               5.458732
# 3        2958.7854           177240050.0               5.303607
# 4        2952.9990           174272690.0               5.153941
# 5        2902.3920           190335310.0               5.013797
# 6        2927.2450           228106560.0               4.875166
# 7        2769.6858           263904210.0               4.738095
# 8        2144.1665           268600640.0               4.606694
# 9        1981.7102           257563813.3               4.476813
# 10       1992.4244           267109531.3               4.301709
# 11      12727.0830           206121730.0               0.931842
# 12      12979.7650           200329040.0               0.883420
# 13      13306.4430           174448450.0               0.851854
# 14      13769.5470           167901570.0               0.836194
# 15      14306.2990           174245340.0               0.830237
# 16      14918.0810           188615620.0               0.831054
# 17      15290.7770           212183620.0               0.834857
# 18      14869.2200           205696600.0               0.838682
# 19      16353.8090           217860500.0               0.841297
#
#     health_expenditure_per_capita
# 0                      178.079030
# 1                      202.261550
# 2                      215.725230
# 3                      239.188750
# 4                      264.543980
# 5                      299.787500
# 6                      321.499080
# 7                      322.499300
# 8                      363.611180
# 9                      377.981953
# 10                     399.038003
# 11                     666.017640
# 12                     725.737700
# 13                     753.180050
# 14                     811.422060
# 15                     838.417000
# 16                     896.791400
# 17                     981.879000
# 18                    1044.568600
# 19                    1131.669100

# %%
# df = df.reset_index(drop=False)
# df.head(20)
command_str = ('Life_Expectancy L1.Life_Expectancy Annual_CO2_emissions GDP_per_capita  '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita | '
               'gmm(Life_Expectancy, 2:4) iv(Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita) | nolevel collapse')

mydpd = regression.abond(command_str, df, ['Code', 'Year'])
# Out:
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: Code                            Number of obs = 1350
#  Time variable: Year                             Min obs per group: 9
#  Number of instruments = 8                       Max obs per group: 9
#  Number of groups = 150                          Avg obs per group: 9.00
# +-------------------------------+------------+---------------------+------------+-----------+---+
# |        Life_Expectancy        |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------------------+------------+---------------------+------------+-----------+---+
# |       L1.Life_Expectancy      | -0.0000000 |      0.0000000      | -2.2620606 | 0.0236937 | * |
# |      Annual_CO2_emissions     | 0.0000000  |      0.0000000      | 0.7439848  | 0.4568857 |   |
# |         GDP_per_capita        | 0.0000608  |      0.0000269      | 2.2620573  | 0.0236939 | * |
# |      Military_Expenditure     | 0.0000000  |      0.0000000      | 2.3074263  | 0.0210311 | * |
# |     Infant_Mortality_Rate     | -0.0000000 |      0.0000000      | -2.2620573 | 0.0236939 | * |
# | health_expenditure_per_capita | 0.0000025  |      0.0000011      | 2.2620573  | 0.0236939 | * |
# +-------------------------------+------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(2) = 7.274 Prob > Chi2 = 0.026
# Arellano-Bond test for AR(1) in first differences: z = -1.07 Pr > z =0.285
# Arellano-Bond test for AR(2) in first differences: z = -1.89 Pr > z =0.059

# %%
#developed
command_str = ('Life_Expectancy L1.Life_Expectancy Annual_CO2_emissions GDP_per_capita  '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita | '
               'gmm(Life_Expectancy, 2:4) iv(Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita) | nolevel collapse')

mydpd = regression.abond(command_str, df1, ['Code', 'Year'])
# Out:
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: Code                            Number of obs = 783
#  Time variable: Year                             Min obs per group: 9
#  Number of instruments = 8                       Max obs per group: 9
#  Number of groups = 87                           Avg obs per group: 9.00
# +-------------------------------+------------+---------------------+------------+-----------+---+
# |        Life_Expectancy        |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------------------+------------+---------------------+------------+-----------+---+
# |       L1.Life_Expectancy      | -0.0000000 |      0.0000000      | -1.4701048 | 0.1415334 |   |
# |      Annual_CO2_emissions     | 0.0000000  |      0.0000000      | 0.5869429  | 0.5572420 |   |
# |         GDP_per_capita        | 0.0000401  |      0.0000272      | 1.4701058  | 0.1415331 |   |
# |      Military_Expenditure     | 0.0000000  |      0.0000000      | 2.1209176  | 0.0339287 | * |
# |     Infant_Mortality_Rate     | -0.0000000 |      0.0000000      | -1.4701058 | 0.1415331 |   |
# | health_expenditure_per_capita | 0.0000024  |      0.0000016      | 1.4701058  | 0.1415331 |   |
# +-------------------------------+------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(2) = 10.561 Prob > Chi2 = 0.005
# Arellano-Bond test for AR(1) in first differences: z = -3.04 Pr > z =0.002
# Arellano-Bond test for AR(2) in first differences: z = -5.33 Pr > z =0.000

# %%
#developing
command_str = ('Life_Expectancy L1.Life_Expectancy Annual_CO2_emissions GDP_per_capita  '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita | '
               'gmm(Life_Expectancy, 2:4) iv(Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita) | nolevel collapse')

mydpd = regression.abond(command_str, df2, ['Code', 'Year'])
# Out:
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: Code                            Number of obs = 567
#  Time variable: Year                             Min obs per group: 9
#  Number of instruments = 8                       Max obs per group: 9
#  Number of groups = 63                           Avg obs per group: 9.00
# +-------------------------------+------------+---------------------+------------+-----------+----+
# |        Life_Expectancy        |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |    |
# +-------------------------------+------------+---------------------+------------+-----------+----+
# |       L1.Life_Expectancy      | 0.0000430  |      0.0000335      | 1.2850450  | 0.1987766 |    |
# |      Annual_CO2_emissions     | -0.0000000 |      0.0000000      | -0.9648522 | 0.3346189 |    |
# |         GDP_per_capita        | 0.0010330  |      0.0004081      | 2.5313915  | 0.0113611 | *  |
# |      Military_Expenditure     | 0.0000000  |      0.0000000      | 2.7915183  | 0.0052461 | ** |
# |     Infant_Mortality_Rate     | -0.0000217 |      0.0000169      | -1.2817879 | 0.1999171 |    |
# | health_expenditure_per_capita | 0.0074593  |      0.0058555      | 1.2739039  | 0.2026975 |    |
# +-------------------------------+------------+---------------------+------------+-----------+----+
# Hansen test of overid. restrictions: chi(2) = 28.197 Prob > Chi2 = 0.000
# Arellano-Bond test for AR(1) in first differences: z = -1.02 Pr > z =0.308
# Arellano-Bond test for AR(2) in first differences: z = -1.12 Pr > z =0.263

# %%
command_str = ('Life_Expectancy L1.Life_Expectancy Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita | '
               'gmm(Life_Expectancy, 2:4) iv(Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita) | collapse')

mydpd = regression.abond(command_str, df, ['Code', 'Year'])
# Out:
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: Code                             Number of obs = 1350
#  Time variable: Year                              Min obs per group: 9
#  Number of instruments = 10                       Max obs per group: 9
#  Number of groups = 150                           Avg obs per group: 9.00
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# |        Life_Expectancy        |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |     |
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# |       L1.Life_Expectancy      | 0.0000023  |      0.0000002      | 11.0797225 | 0.0000000 | *** |
# |      Annual_CO2_emissions     | 0.0000000  |      0.0000000      | 4.5974574  | 0.0000043 | *** |
# |         GDP_per_capita        | 0.0015122  |      0.0001365      | 11.0797271 | 0.0000000 | *** |
# |      Military_Expenditure     | -0.0000000 |      0.0000000      | -3.5843728 | 0.0003379 | *** |
# |     Infant_Mortality_Rate     | 0.0000000  |      0.0000000      | 11.0797271 | 0.0000000 | *** |
# | health_expenditure_per_capita | 0.0000988  |      0.0000089      | 11.0797271 | 0.0000000 | *** |
# |              _con             | 0.0000000  |      0.0000000      | 11.0797271 | 0.0000000 | *** |
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# Hansen test of overid. restrictions: chi(3) = 0.000 Prob > Chi2 = 1.000
# Arellano-Bond test for AR(1) in first differences: z = -0.84 Pr > z =0.403
# Arellano-Bond test for AR(2) in first differences: z = -0.33 Pr > z =0.743

# %%
#developed
command_str = ('Life_Expectancy L1.Life_Expectancy Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita | '
               'gmm(Life_Expectancy, 2:4) iv(Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita) | collapse')

mydpd = regression.abond(command_str, df1, ['Code', 'Year'])
# Out:
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: Code                             Number of obs = 783
#  Time variable: Year                              Min obs per group: 9
#  Number of instruments = 10                       Max obs per group: 9
#  Number of groups = 87                            Avg obs per group: 9.00
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# |        Life_Expectancy        |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |     |
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# |       L1.Life_Expectancy      | 0.0000020  |      0.0000002      | 11.5543858 | 0.0000000 | *** |
# |      Annual_CO2_emissions     | 0.0000000  |      0.0000000      | 4.5863610  | 0.0000045 | *** |
# |         GDP_per_capita        | 0.0014097  |      0.0001220      | 11.5544110 | 0.0000000 | *** |
# |      Military_Expenditure     | -0.0000000 |      0.0000000      | -3.3862115 | 0.0007086 | *** |
# |     Infant_Mortality_Rate     | 0.0000000  |      0.0000000      | 11.5544110 | 0.0000000 | *** |
# | health_expenditure_per_capita | 0.0000923  |      0.0000080      | 11.5544110 | 0.0000000 | *** |
# |              _con             | 0.0000000  |      0.0000000      | 11.5544110 | 0.0000000 | *** |
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# Hansen test of overid. restrictions: chi(3) = 0.000 Prob > Chi2 = 1.000
# Arellano-Bond test for AR(1) in first differences: z = 0.14 Pr > z =0.892
# Arellano-Bond test for AR(2) in first differences: z = 0.44 Pr > z =0.658

# %%
#developing
command_str = ('Life_Expectancy L1.Life_Expectancy Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita | '
               'gmm(Life_Expectancy, 2:4) iv(Annual_CO2_emissions GDP_per_capita '
               'Military_Expenditure Infant_Mortality_Rate health_expenditure_per_capita) | collapse')

mydpd = regression.abond(command_str, df2, ['Code', 'Year'])
# Out:
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: Code                             Number of obs = 567
#  Time variable: Year                              Min obs per group: 9
#  Number of instruments = 10                       Max obs per group: 9
#  Number of groups = 63                            Avg obs per group: 9.00
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# |        Life_Expectancy        |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |     |
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# |       L1.Life_Expectancy      | 0.0000806  |      0.0000060      | 13.3337802 | 0.0000000 | *** |
# |      Annual_CO2_emissions     | -0.0000000 |      0.0000001      | -0.0082034 | 0.9934547 |     |
# |         GDP_per_capita        | 0.0089857  |      0.0006739      | 13.3337569 | 0.0000000 | *** |
# |      Military_Expenditure     | 0.0000000  |      0.0000000      | 0.0124441  | 0.9900713 |     |
# |     Infant_Mortality_Rate     | 0.0000038  |      0.0000003      | 13.3337569 | 0.0000000 | *** |
# | health_expenditure_per_capita | 0.0004468  |      0.0000335      | 13.3337569 | 0.0000000 | *** |
# |              _con             | 0.0000012  |      0.0000001      | 13.3337569 | 0.0000000 | *** |
# +-------------------------------+------------+---------------------+------------+-----------+-----+
# Hansen test of overid. restrictions: chi(3) = 1.381 Prob > Chi2 = 0.710
# Arellano-Bond test for AR(1) in first differences: z = -0.74 Pr > z =0.459
# Arellano-Bond test for AR(2) in first differences: z = -0.41 Pr > z =0.680
